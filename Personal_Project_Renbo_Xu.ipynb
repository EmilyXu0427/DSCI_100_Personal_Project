# %% [markdown]
# Title

# %%
library(tidyverse)
# Out:
# Warning message:
# “package ‘ggplot2’ was built under R version 4.3.2”
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.5.0     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
# Create column names for the data set
column_names <- c('age','sex','cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalac', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num')

cleveland_df = read_csv("data/heart_disease/processed.cleveland.data", col_names = column_names) 
hungarian_df = read_csv("data/heart_disease/processed.hungarian.data", col_names = column_names) 
switzerland_df = read_csv("data/heart_disease/processed.switzerland.data", col_names = column_names) 
va_df = read_csv("data/heart_disease/processed.va.data", col_names = column_names)
# Out:
# Rows: 303 Columns: 14
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (2): ca, thal
# dbl (12): age, sex, cp, trestbps, chol, fbs, restecg, thalac, exang, oldpeak...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 294 Columns: 14
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (9): trestbps, chol, fbs, restecg, thalac, exang, slope, ca, thal
# dbl (5): age, sex, cp, oldpeak, num
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 123 Columns: 14
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (9): trestbps, fbs, restecg, thalac, exang, oldpeak, slope, ca, thal
# ...

# %%
cleveland_df
# Out:
#     age sex cp trestbps chol fbs restecg thalac exang oldpeak slope ca  thal
# 1   63  1   1  145      233  1   2       150    0     2.3     3     0.0 6.0
# 2   67  1   4  160      286  0   2       108    1     1.5     2     3.0 3.0
# 3   67  1   4  120      229  0   2       129    1     2.6     2     2.0 7.0
# 4   37  1   3  130      250  0   0       187    0     3.5     3     0.0 3.0
# 5   41  0   2  130      204  0   2       172    0     1.4     1     0.0 3.0
# 6   56  1   2  120      236  0   0       178    0     0.8     1     0.0 3.0
# 7   62  0   4  140      268  0   2       160    0     3.6     3     2.0 3.0
# 8   57  0   4  120      354  0   0       163    1     0.6     1     0.0 3.0
# 9   63  1   4  130      254  0   2       147    0     1.4     2     1.0 7.0
# 10  53  1   4  140      203  1   2       155    1     3.1     3     0.0 7.0
# 11  57  1   4  140      192  0   0       148    0     0.4     2     0.0 6.0
# ...

# %%
hungarian_df
# Out:
#     age sex cp trestbps chol fbs restecg thalac exang oldpeak slope ca thal num
# 1   28  1   2  130      132  0   2       185    0     0       ?     ?  ?    0
# 2   29  1   2  120      243  0   0       160    0     0       ?     ?  ?    0
# 3   29  1   2  140      ?    0   0       170    0     0       ?     ?  ?    0
# 4   30  0   1  170      237  0   1       170    0     0       ?     ?  6    0
# 5   31  0   2  100      219  0   1       150    0     0       ?     ?  ?    0
# 6   32  0   2  105      198  0   0       165    0     0       ?     ?  ?    0
# 7   32  1   2  110      225  0   0       184    0     0       ?     ?  ?    0
# 8   32  1   2  125      254  0   0       155    0     0       ?     ?  ?    0
# 9   33  1   3  120      298  0   0       185    0     0       ?     ?  ?    0
# 10  34  0   2  130      161  0   0       190    0     0       ?     ?  ?    0
# 11  34  1   2  150      214  0   1       168    0     0       ?     ?  ?    0
# ...

# %%
switzerland_df
# Out:
#     age sex cp trestbps chol fbs restecg thalac exang oldpeak slope ca thal num
# 1   32  1   1  95       0    ?   0       127    0     .7      1     ?  ?    1
# 2   34  1   4  115      0    ?   ?       154    0     .2      1     ?  ?    1
# 3   35  1   4  ?        0    ?   0       130    1     ?       ?     ?  7    3
# 4   36  1   4  110      0    ?   0       125    1     1       2     ?  6    1
# 5   38  0   4  105      0    ?   0       166    0     2.8     1     ?  ?    2
# 6   38  0   4  110      0    0   0       156    0     0       2     ?  3    1
# 7   38  1   3  100      0    ?   0       179    0     -1.1    1     ?  ?    0
# 8   38  1   3  115      0    0   0       128    1     0       2     ?  7    1
# 9   38  1   4  135      0    ?   0       150    0     0       ?     ?  3    2
# 10  38  1   4  150      0    ?   0       120    1     ?       ?     ?  3    1
# 11  40  1   4  95       0    ?   1       144    0     0       1     ?  ?    2
# ...

# %%
va_df
# Out:
#     age sex cp trestbps chol fbs restecg thalac exang oldpeak slope ca thal num
# 1   63  1   4  140      260  0   1       112    1     3       2     ?  ?    2
# 2   44  1   4  130      209  0   1       127    0     0       ?     ?  ?    0
# 3   60  1   4  132      218  0   1       140    1     1.5     3     ?  ?    2
# 4   55  1   4  142      228  0   1       149    1     2.5     1     ?  ?    1
# 5   66  1   3  110      213  1   2       99     1     1.3     2     ?  ?    0
# 6   66  1   3  120      0    0   1       120    0     -0.5    1     ?  ?    0
# 7   65  1   4  150      236  1   1       105    1     0       ?     ?  ?    3
# 8   60  1   3  180      0    0   1       140    1     1.5     2     ?  ?    0
# 9   60  1   3  120      0    ?   0       141    1     2       1     ?  ?    3
# 10  60  1   2  160      267  1   1       157    0     0.5     2     ?  ?    1
# 11  56  1   2  126      166  0   1       140    0     0       ?     ?  ?    0
# ...
